# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as style
import scipy.stats as stats
import warnings 
warnings.filterwarnings('ignore')

# %%
style.use('fivethirtyeight')
plt.rcParams['figure.figsize']=(12,6)
plt.rcParams['figure.dpi']=150
plt.rcParams['font.family']=['SimHei']
plt.rcParams['axes.unicode_minus']=False

# %%
df=pd.read_excel('./茅台股份.xlsx')

# %%
df.head()
# Out:
#           日期       开盘       收盘    涨跌额     涨跌幅       最低       最高  成交量(手)  \
# 0 2020-02-05   985.00  1049.99  -2.81 -0.0027   980.00  1057.00  233485
# 1 2020-01-23  1111.86  1052.80 -54.70 -0.0494  1037.00  1111.86  157934
# 2 2020-01-17  1112.50  1107.50  -5.00 -0.0045  1101.01  1129.20  146354
# 3 2020-01-10  1070.86  1112.50  33.94  0.0315  1067.30  1115.99  209658
# 4 2020-01-03  1170.20  1078.56 -84.44 -0.0726  1076.90  1195.50  341767
#
#       成交金额(万)     换手率
# 0  2376181.50  0.0099
# 1  1691490.88  0.0029
# 2  1630883.00  0.0032
# 3  2289939.25  0.0051
# 4  3845760.50  0.0034

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913 entries, 0 to 912
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   日期       913 non-null    datetime64[ns]
#  1   开盘       913 non-null    float64
#  2   收盘       913 non-null    float64
#  3   涨跌额      913 non-null    float64
#  4   涨跌幅      913 non-null    float64
#  5   最低       913 non-null    float64
#  6   最高       913 non-null    float64
#  7   成交量(手)   913 non-null    int64
#  8   成交金额(万)  913 non-null    float64
#  9   换手率      913 non-null    float64
# dtypes: datetime64[ns](1), float64(8), int64(1)
# memory usage: 71.5 KB

# %%
data=df.loc[:,['开盘','最高','最低','收盘']]

# %%
df.set_index('日期').loc[:,['开盘','最高','最低','收盘']].plot()

# %% [markdown]
# ### K线图

# %%
import mpl_finance as mf
import matplotlib.dates as dates
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-81694259c06b> in <module>
# ----> 1 import mpl_finance as mf
#       2 import matplotlib.dates as dates
#
# ModuleNotFoundError: No module named 'mpl_finance'

# %%
df2=df.set_index('日期')

# %%
ohlc=df2.loc[:,['开盘','最高','最低','收盘']]

# %%
ax=plt.subplot()

# %%
mf.candlestick2_ohlc(ax,(dates.date2num(df2.index),ohlc.开盘,ohlc.最高,ohlc.最低,ohlc.收盘))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-1ead25e52cec> in <module>
# ----> 1 mf.candlestick2_ohlc(ax,(dates.date2num(df2.index),ohlc.开盘,ohlc.最高,ohlc.最低,ohlc.收盘))
#
# NameError: name 'mf' is not defined

# %%
ax.plot(dates.date2num(df2.index),res.最高,lw=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-152080166d66> in <module>
# ----> 1 ax.plot(dates.date2num(df2.index),res.最高,lw=1)
#
# NameError: name 'dates' is not defined

# %%
ax.xaxis_date()
plt.xticks(rotation=45)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  <a list of 6 Text major ticklabel objects>)
